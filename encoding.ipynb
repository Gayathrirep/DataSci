# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('imputed_vals.csv')
df.head()
# Out:
#          ID  Gender    CustomerType   Age       TypeTravel Travel_Class  \
# 0  98800001  Female  Loyal Customer  52.0  Business travel     Business
# 1  98800002    Male  Loyal Customer  48.0  Personal Travel          Eco
# 2  98800003  Female  Loyal Customer  43.0  Business travel     Business
# 3  98800004  Female  Loyal Customer  44.0  Business travel     Business
# 4  98800005  Female  Loyal Customer  50.0  Business travel     Business
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0
#
#    Overall_Experience  ... Onboardwifi_service Onboard_entertainment  \
# 0                   0  ...                good      need improvement
# 1                   0  ...                good                  poor
# 2                   1  ...    need improvement                  good
# 3                   0  ...          acceptable      need improvement
# 4                   1  ...    need improvement                  good
#
#   Online_support Onlinebooking_Ease   Onboard_service          Leg_room  \
# 0     acceptable   need improvement  need improvement        acceptable
# 1           good               good         excellent  need improvement
# 2      excellent          excellent         excellent         excellent
# 3     acceptable         acceptable        acceptable        acceptable
# 4      excellent               good              good              good
#
#    Baggage_handling   Checkin_service       Cleanliness Online_boarding
# 0  need improvement              good  need improvement            poor
# 1              poor  need improvement              good            good
# 2         excellent              good         excellent       excellent
# 3        acceptable              good        acceptable      acceptable
# 4              good              good              good            good
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Encoding Travel Data

# %%
values = df['Travel_Class'].unique()
values
# Out:
# array(['Business', 'Eco'], dtype=object)

# %%
df['Travel_Class'] = df['Travel_Class'].map({
    'Business':1,
    'Eco':2
})

# %%
df['CustomerType'] = df['CustomerType'].map({
    'nan':'',
    'Loyal Customer':1,
    'disloyal Customer':2
})

# %%
df['TypeTravel'] = df['TypeTravel'].map({
    'nan':'',
    'Personal Travel':1,
    'Business travel':2
})

# %%
df['Gender'] = df['Gender'].map({
    'nan':'',
    'Female':1,
    'Male':2
})

# %% [markdown]
# for feature in df_survey.columns:
#     if df_survey[feature].dtype == 'object':
#         df_survey[feature] = pd.Categorical(df_survey[feature]).codes

# %%
df.head()
# Out:
#          ID Gender CustomerType   Age TypeTravel  Travel_Class  \
# 0  98800001      1            1  52.0          2             1
# 1  98800002      2            1  48.0          1             2
# 2  98800003      1            1  43.0          2             1
# 3  98800004      1            1  44.0          2             1
# 4  98800005      1            1  50.0          2             1
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0
#
#    Overall_Experience  ... Onboardwifi_service Onboard_entertainment  \
# 0                   0  ...                good      need improvement
# 1                   0  ...                good                  poor
# 2                   1  ...    need improvement                  good
# 3                   0  ...          acceptable      need improvement
# 4                   1  ...    need improvement                  good
#
#   Online_support Onlinebooking_Ease   Onboard_service          Leg_room  \
# 0     acceptable   need improvement  need improvement        acceptable
# 1           good               good         excellent  need improvement
# 2      excellent          excellent         excellent         excellent
# 3     acceptable         acceptable        acceptable        acceptable
# 4      excellent               good              good              good
#
#    Baggage_handling   Checkin_service       Cleanliness Online_boarding
# 0  need improvement              good  need improvement            poor
# 1              poor  need improvement              good            good
# 2         excellent              good         excellent       excellent
# 3        acceptable              good        acceptable      acceptable
# 4              good              good              good            good
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Encoding Survey Data

# %%
map_values = {
    'nan':'',
    'extremely poor':1,  
     'poor':2,
    'good':3,
    'acceptable':4,
    'need improvement':5,
    'excellent':6,   
}

# %%
services = ['Seat_comfort', 'Arrival_time_convenient', 'Catering', 'Onboardwifi_service', 'Online_support',
           'Onlinebooking_Ease', 'Onboard_service', 'Leg_room', 'Baggage_handling', 'Checkin_service',
           'Cleanliness', 'Online_boarding', 'Onboard_entertainment']

# %%
for service in services:
    df[service] = df[service].map(map_values)

# %%
df.head()
# Out:
#          ID Gender CustomerType   Age TypeTravel  Travel_Class  \
# 0  98800001      1            1  52.0          2             1
# 1  98800002      2            1  48.0          1             2
# 2  98800003      1            1  43.0          2             1
# 3  98800004      1            1  44.0          2             1
# 4  98800005      1            1  50.0          2             1
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0
#
#    Overall_Experience  ... Onboardwifi_service Onboard_entertainment  \
# 0                   0  ...                   3                     5
# 1                   0  ...                   3                     2
# 2                   1  ...                   5                     3
# 3                   0  ...                   4                     5
# 4                   1  ...                   5                     3
#
#   Online_support Onlinebooking_Ease Onboard_service Leg_room Baggage_handling  \
# 0              4                  5               5        4                5
# 1              3                  3               6        5                2
# 2              6                  6               6        6                6
# 3              4                  4               4        4                4
# 4              6                  3               3        3                3
#
#   Checkin_service Cleanliness Online_boarding
# 0               3           5               2
# 1               5           3               3
# 2               3           6               6
# 3               3           4               4
# 4               3           3               3
#
# [5 rows x 25 columns]

# %%
df['Seat_Class'] = df['Seat_Class'].map({
    'Green Car': 1,
    'Ordinary' : 0,
})

# %%
df['Platform_location'].unique()
# Out:
# array(['very convinient', 'need improvement', 'manageable',
#        'Inconvinient', 'Convinient', 'very inconvinient'], dtype=object)

# %%
df['Platform_location'] = df['Platform_location'].map({
    'nan':'',
    'very inconvinient':1,
    'need improvement':3,
    'Inconvinient':2,   
    'manageable':4,     
    'Convinient':5, 
    'very convinient':6,
})

# %%
df.head()
# Out:
#          ID Gender CustomerType   Age TypeTravel  Travel_Class  \
# 0  98800001      1            1  52.0          2             1
# 1  98800002      2            1  48.0          1             2
# 2  98800003      1            1  43.0          2             1
# 3  98800004      1            1  44.0          2             1
# 4  98800005      1            1  50.0          2             1
#
#    Travel_Distance  DepartureDelay_in_Mins  ArrivalDelay_in_Mins  \
# 0              272                     0.0                   5.0
# 1             2200                     9.0                   0.0
# 2             1061                    77.0                 119.0
# 3              780                    13.0                  18.0
# 4             1981                     0.0                   0.0
#
#    Overall_Experience  ... Onboardwifi_service  Onboard_entertainment  \
# 0                   0  ...                   3                      5
# 1                   0  ...                   3                      2
# 2                   1  ...                   5                      3
# 3                   0  ...                   4                      5
# 4                   1  ...                   5                      3
#
#   Online_support Onlinebooking_Ease Onboard_service Leg_room Baggage_handling  \
# 0              4                  5               5        4                5
# 1              3                  3               6        5                2
# 2              6                  6               6        6                6
# 3              4                  4               4        4                4
# 4              6                  3               3        3                3
#
#   Checkin_service Cleanliness Online_boarding
# 0               3           5               2
# 1               5           3               3
# 2               3           6               6
# 3               3           4               4
# 4               3           3               3
#
# [5 rows x 25 columns]

# %%
df.set_index('ID', inplace=True)
df.head()
# Out:
#          Gender CustomerType   Age TypeTravel  Travel_Class  Travel_Distance  \
# ID
# 98800001      1            1  52.0          2             1              272
# 98800002      2            1  48.0          1             2             2200
# 98800003      1            1  43.0          2             1             1061
# 98800004      1            1  44.0          2             1              780
# 98800005      1            1  50.0          2             1             1981
#
#           DepartureDelay_in_Mins  ArrivalDelay_in_Mins  Overall_Experience  \
# ID
# 98800001                     0.0                   5.0                   0
# 98800002                     9.0                   0.0                   0
# 98800003                    77.0                 119.0                   1
# 98800004                    13.0                  18.0                   0
# 98800005                     0.0                   0.0                   1
#
#          Seat_comfort  ...  Onboardwifi_service Onboard_entertainment  \
# ID                     ...
# 98800001            5  ...                    3                     5
# 98800002            2  ...                    3                     2
# 98800003            5  ...                    5                     3
# 98800004            4  ...                    4                     5
# 98800005            4  ...                    5                     3
#
#          Online_support Onlinebooking_Ease Onboard_service Leg_room  \
# ID
# 98800001              4                  5               5        4
# 98800002              3                  3               6        5
# 98800003              6                  6               6        6
# 98800004              4                  4               4        4
# 98800005              6                  3               3        3
#
#          Baggage_handling Checkin_service Cleanliness Online_boarding
# ID
# 98800001                5               3           5               2
# 98800002                2               5           3               3
# 98800003                6               3           6               6
# 98800004                4               3           4               4
# 98800005                3               3           3               3
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Gender', 'CustomerType', 'Age', 'TypeTravel', 'Travel_Class',
#        'Travel_Distance', 'DepartureDelay_in_Mins', 'ArrivalDelay_in_Mins',
#        'Overall_Experience', 'Seat_comfort', 'Seat_Class',
#        'Arrival_time_convenient', 'Catering', 'Platform_location',
#        'Onboardwifi_service', 'Onboard_entertainment', 'Online_support',
#        'Onlinebooking_Ease', 'Onboard_service', 'Leg_room', 'Baggage_handling',
#        'Checkin_service', 'Cleanliness', 'Online_boarding'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94379 entries, 98800001 to 98894379
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   94379 non-null  object
#  1   CustomerType             94379 non-null  object
#  2   Age                      94379 non-null  float64
#  3   TypeTravel               94379 non-null  object
#  4   Travel_Class             94379 non-null  int64
#  5   Travel_Distance          94379 non-null  int64
#  6   DepartureDelay_in_Mins   94379 non-null  float64
#  7   ArrivalDelay_in_Mins     94379 non-null  float64
#  8   Overall_Experience       94379 non-null  int64
#  9   Seat_comfort             94379 non-null  object
#  10  Seat_Class               94379 non-null  int64
#  11  Arrival_time_convenient  94379 non-null  object
#  12  Catering                 94379 non-null  object
#  13  Platform_location        94379 non-null  object
#  14  Onboardwifi_service      94379 non-null  object
#  15  Onboard_entertainment    94379 non-null  object
#  16  Online_support           94379 non-null  object
#  17  Onlinebooking_Ease       94379 non-null  object
#  18  Onboard_service          94379 non-null  object
#  19  Leg_room                 94379 non-null  object
#  20  Baggage_handling         94379 non-null  object
#  21  Checkin_service          94379 non-null  object
#  22  Cleanliness              94379 non-null  object
#  23  Online_boarding          94379 non-null  object
# dtypes: float64(3), int64(4), object(17)
# memory usage: 18.0+ MB

# %%
df[['ArrivalDelay_in_Mins']].boxplot()
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()

ax1 = sns.heatmap(corr, cbar=0, linewidths=2,vmax=1, vmin=0, square=True, cmap='Blues')
plt.show()
